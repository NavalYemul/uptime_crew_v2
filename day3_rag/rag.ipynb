# %%
#%pip uninstall -y langchain langchain-core langchain-community langchain-openai
# %pip install -U langchain langchain-core langchain-community langchain-openai langchain-chroma
# Out:
# Requirement already satisfied: langchain in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (1.2.15)
# Requirement already satisfied: langchain-core in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (1.2.27)
# Requirement already satisfied: langchain-community in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (0.4.1)
# Requirement already satisfied: langchain-openai in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (1.1.12)
# Requirement already satisfied: langchain-chroma in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (1.1.0)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langchain) (1.1.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langchain-core) (0.7.26)
# Requirement already satisfied: packaging>=23.2.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langchain-core) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langchain-core) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.33.1)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.13.0)
# Requirement already satisfied: certifi in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langchain-community) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langchain-community) (1.4.54)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langchain-community) (2.4.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.6.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langchain-openai) (2.30.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.13.0)
# Requirement already satisfied: sniffio in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.4.4)
# Requirement already satisfied: chromadb<2.0.0,>=1.3.5 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from langchain-chroma) (1.5.6)
# Requirement already satisfied: build>=1.0.3 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.2)
# Requirement already satisfied: pybase64>=1.4.1 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.44.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.24.4)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.40.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.40.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.51.1)
# Requirement already satisfied: overrides>=7.3.1 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.80.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.26.0)
# Requirement already satisfied: pyproject_hooks in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.10)
# Requirement already satisfied: flatbuffers in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (25.12.19)
# Requirement already satisfied: protobuf in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.33.6)
# Requirement already satisfied: sympy in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.74.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.40.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.40.0)
# Requirement already satisfied: opentelemetry-proto==1.40.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.61b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.9.0)
# Requirement already satisfied: filelock>=3.10.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2026.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.3)
# Requirement already satisfied: click>=8.2.1 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/navalyemul/Documents/uptime/venv/lib/python3.13/site-packages (from sympy->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv

load_dotenv()

openai_key = os.getenv("OPENAI_API_KEY")

print("Keys loaded ✅")
# Out:
# Keys loaded ✅

# %%
llm = ChatOpenAI(
    model="gpt-4o-mini",
)

# %%
from langchain_openai import ChatOpenAI

#llm=ChatOpenAI(model="gpt-4o-mini")

question=input("Enter the question")

response=llm.invoke(question)
print(response.content)
# Out:
# A cursor is a movable indicator on a computer screen that shows the user's current position for input or selection. It can take various forms, such as a blinking vertical line (in text editing), an arrow (for pointing and clicking), or a hand (for indicating clickable items).
#
# In programming and databases, a cursor also refers to a database object used to retrieve, manipulate, and navigate through a result set of a query. It allows developers to process individual rows returned by a SQL statement sequentially, which can be useful for operations like iterating through records to perform updates or calculations.
#
# In summary, the specific meaning of "cursor" depends on the context:
#
# 1. **User Interface**: An indicator for user input and navigation.
# 2. **Database**: A database object for handling query results.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate

#lm=ChatOpenAI(model="gpt-4")

prompt_template=PromptTemplate(
    input_variable=["country"],
    template="""You are an expert in traditional cuisines.
    You provide information about a specific dish from a specific country.
    Answer the question: What is the traditional cuisine of {country}
    """
)

response=llm.invoke(prompt_template.format(country="India"))
print(response.content)
# Out:
# Indian cuisine is incredibly diverse, reflecting the country's varied geography, climate, culture, and history. One quintessential dish that embodies the richness of Indian traditional cuisine is **Biryani**.
#
# ### Biryani
#
# #### Overview:
# Biryani is a fragrant rice dish distinguished by its use of various spices, herbs, and marinated meat (commonly chicken, lamb, or goat) or vegetables. It is believed to have been brought to India by Persian travelers and merchants. Over time, it has evolved into numerous regional variations.
#
# #### Ingredients:
# - **Rice:** Traditionally, long-grain basmati rice is used for its aroma and fluffy texture.
# - **Meat/Vegetables:** Marinated with yogurt and spices, usually including saffron or turmeric for color and flavor.
# - **Spices:** A blend of warm spices such as cardamom, cinnamon, cloves, and bay leaves, along with cumin and coriander.
# - **Herbs:** Fresh cilantro and mint can be used to garnish, adding freshness.
# - **Onions and Tomatoes:** Fried onions add sweetness and depth, while tomatoes can contribute acidity.
#
# #### Cooking Method:
# Biryani is typically prepared using two primary methods:
# 1. **Kacchi Biryani:** Where marinated raw meat is layered with partially cooked rice and then slow-cooked (dum style) to allow flavors to meld.
# 2. **Pakki Biryani:** Where the meat is cooked separately before being layered with fully cooked rice and then finished together.
#
# #### Regional Variations:
# - **Hyderabadi Biryani:** Known for its usage of saffron and a blend of spicy seasonings, and often features a yogurt marinade.
# - **Lucknowi (Awadhi) Biryani:** Characterized by a subtle flavor profile, often cooked using the slow-cooking (dum) method.
# - **Kolkata Biryani:** Distinct for the addition of potatoes and boiled eggs, and a slightly sweeter taste.
#
# ### Cultural Significance:
# Biryani is often served during special occasions, festivals, and celebrations. It symbolizes hospitality and is a staple at weddings and feasts, showcasing India’s rich culinary heritage.
#
# Exploring biryani not only introduces one to a delicious dish but also offers insight into the local customs, traditions, and the art of Indian cooking.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate

llm=ChatOpenAI(model="gpt-4")

prompt_template=PromptTemplate(
    input_variable=["country","no_of_para","language"],
    template="""You are an expert in traditional cuisines.
    You provide information about a specific dish from a specific country.
    Avoid giving information about fictional places. If its fictional place just give output as 'I dont know'.
    Answer the question: What is the traditional cuisine of {country}.
    Answer in {no_of_para} paragraphs in {language} language.
    """
)

response=llm.invoke(prompt_template.format(country="India",no_of_para=2,language="Kanada"))
print(response.content)
# Out:
# ಭಾರತದ ಸಾಂಪ್ರದಾಯಿಕ ಆಹಾರ ಅತ್ಯಂತ ವಿವಿಧವಾಗಿದೆ ಮತ್ತು ಅದು ಪ್ರಾಂತೀಯ ವೈವಿಧ್ಯಗಳನ್ನು ಪ್ರತಿಪಾದಿಸುತ್ತದೆ. 'ಬಿರ್ಯಾನಿ', 'ಸಮೋಸಾ', 'ಪಾವ್ ಭಾಜಿ', 'ಕೆಮ್ಪು ಕಾರೀ ಅನ್ನ', 'ದೋಸೆ' ಮತ್ತು 'ಬೇಲ್ ಪೂರಿ' ಇತ್ಯಾದಿ ಭಾರತದ ಪ್ರಮುಖ ಆಹಾರಗಳು. ಕುಂಡಪುರ, ಉಡುಪಿ, ಮಂಗಳೂರು, ಮೈಸೂರು, ಬೆಲಗಾವಿ, ದಕ್ಷಿಣ ಕನ್ನಡ ಮತ್ತು ಉತ್ತರ ಕನ್ನಡ ಪ್ರಾಂತ್ಯಗಳು ಕನ್ನಡ ಆಹಾರ ವಿವಿಧತೆಗೆ ಬೇಲಿ ಹಾಕಲಾಗಿದೆ.
#
# ನಮ್ಮ ಸಂಪ್ರದಾಯದಲ್ಲಿ ಆಹಾರ ಮುಖ್ಯವಾಗಿ ಅನ್ನ, ಅಕ್ಕಿ ರೊಟ್ಟಿ ಮತ್ತು ಸಾರುವಿನ ಮೇಲೆ ಆಧಾರಿತವಾಗಿದೆ. ಮಾಜೀಗೆ ಸಾರು, ಬಿಸಿಬೇಳೆ ಬಾತು, ಹುಲಿಸಾರು, ವೈರೇಟಿ ರೈತಾಗಳು, ಪಲ್ಯ ಮತ್ತು ಕೊಸಮ್ಬರಿಗಳು, ಅಕ್ಕಿ ರೊಟ್ಟಿಗಳು, ಜೋಳದ ರೊಟ್ಟಿ, ರಗಿ ಮೀಗಿಗೆಗಳು ಮತ್ತು ಹೋಳಿಗೆ - ಒಮ್ಮೆ ಖಾದಿಸಿ ನೋಡಿ. ಇವು ಅತ್ಯಂತ ರುಚಿಯುತವಾದವು ಮತ್ತು ಆರೋಗ್ಯಕರವಾದವು. ಈ ಆಹಾರಗಳು ನಮ್ಮನ್ನು ಜೀವನದಲ್ಲಿ ಬಹುಮುಖ್ಯ ಆರೋಗ್ಯವನ್ನು ಪಡೆಯುವಂತೆ ಮಾಡುತ್ತವೆ.

# %% [markdown]
# # Task
# Welcome to the {city} travel guide!.
#     If you're visiting in {month}, here's what you can do:
#     1.Must- Visit attractions.
#     2.Local Cuisine
#     3.Useful phrases in {language}.
#     4.Tips for travelling on a {budget} budget

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate

llm=ChatOpenAI(model="gpt-4")

prompt_template = PromptTemplate(
    input_variables=[
        "city",
        "month",
        "language",
        "budget"
    ],
    template=(
        "Welcome to the {city} travel guide!\n"
        "If you're visiting in {month}, here is a detailed guide to help you make the most of your trip:\n"
        "Start by exploring the must-visit attractions that showcase the unique culture and history of {city}. "
        "Indulge in the local cuisine, with recommendations for dishes and restaurants that fit your taste and budget. "
        "Learn a few useful phrases in {language} to enhance your travel experience and connect with locals. "
        "Finally, discover practical tips for traveling on a {budget} budget, including affordable accommodation, transportation, and activities.\n"
        "Please provide the information in a single, well-structured paragraph."
    )
)
print("Travel Guide App")

city=input("enter your travel city")
month=input("enter your travel month")
language=input("enter your language")
budget=input("enter your budget")


if city:
    response=llm.invoke(prompt_template.format(city=city,month=month,language=language,budget=budget))
    print(response.content)

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate

llm=ChatOpenAI(model="gpt-4")

title_prompt=PromptTemplate(
    input_variable=["topic"],
    template="""You are an experienced speech writer.
    You need to craft an impactful title for a speech 
    on the following topic: {topic}
    Answer exactly with one title.	
    """)

speech_prompt=PromptTemplate(
    input_variable=["title"],
    template="""You need to write a powerful speech of 250 words 
    for the following title:{title}
    """)

first_chain= title_prompt| llm # generate title 
second_chain=speech_prompt | llm # generate speech
final_chain=first_chain | second_chain

topic=input("Enter the topic name: ")

#chain=first_chain | second_chain

if topic:
    response=final_chain.invoke({"topic":topic})
    print(response.content)
# Out:
# Ladies and Gentlemen,
#
# We stand united on the threshold of a magnificent tomorrow. We are witnesses to an era of mind-boggling breakthroughs fueled by the power and promise of Artificial Intelligence. However, no achievement shines brighter than the rise of Generative AI. Yes, welcome to the dawn of a new age!
#
# Once limited to simple, mundane tasks, AI has evolved to mimic the human mind's creativity, birthing endless possibilities. Generative AI is not just a computational powerhouse; it is the embodiment of imagination and innovation unparalleled. Today, we're not just writing codes; we're scripting destinies.
#
# This AI revolution is effectively blurring the lines between man and machine, between creator and creation. It's opening doors to dimensions previously untraversable - creating arts, constructing dramas, composing music, and even crafting scientific theories!
#
# The startling brilliance of Generative AI rests upon its uncanny ability to learn and morph, to innovate and create, to perceive patterns and conceive perfection. Today, the creativity of humanity converges with the capabilities of AI, opening a universe of opportunities not confined by human limitations.
#
# As we unveil the future, let's herald the dawn of limitless possibilities, where dreams are no longer dreams but palpable realities crafted by our digital co-creator – Generative AI.
#
# Remember, the future is not about possession, it's about creation; it's not about competition, it's about collaboration. So, let us intertwine our brilliance with AI's capabilities. Together, let us paint future's canvas, unveil the veil of impossibility to explore the unimaginable! Ladies and Gentlemen, to the Rise of Generative AI!

# %% [markdown]
# #Task
# Use 2 different LLMS.
#
# Blog Post Generator:
#   You are a professional blogger.
#     Create an outline for a blog post on the following topic: {topic}
#     The outline should include:
#     - Introduction
#     - 3 main points with subpoints
#     - Conclusion
#
#
#   You are a professional blogger.
#     Write an engaging introduction paragraph based on the following
#     outline:{outline}
#     The introduction should hook the reader and provide a brief
#     overview of the topic

# %%
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma
from langchain_core.prompts import PromptTemplate

# ✅ NEW IMPORTS (this environment provides these via langchain_classic)
from langchain_classic.chains import create_retrieval_chain
from langchain_classic.chains.combine_documents import create_stuff_documents_chain

# %%
# =========================
# 1. Load Data
# =========================
# File lives next to this notebook: day3_rag/product-data .txt
document = TextLoader("./product-data .txt").load()

# =========================
# 2. Split into chunks
# =========================
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=100
)

chunks = text_splitter.split_documents(document)

# =========================
# 3. OpenAI Embeddings
# =========================
embeddings = OpenAIEmbeddings(
    model="text-embedding-3-small",  # or text-embedding-3-large
)

# =========================
# 4. Vector Store (Chroma)
# =========================
vector_store = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings
)

# =========================
# 5. Retriever
# =========================
retriever = vector_store.as_retriever(
    search_kwargs={"k": 3}
)

# =========================
# 6. LLM (OpenAI)
# =========================

llm = ChatOpenAI(
    model="gpt-4o-mini",

# =========================
# 7. Prompt
# =========================
prompt_template = PromptTemplate(
    input_variables=["context", "input"],
    template="""
You are an assistant for answering questions.

Use ONLY the provided context.
If the answer is not available, say "I don't know".

Answer in maximum 3 concise sentences.

Context:
{context}

Question:
{input}
"""
)

# =========================
# 8. Chains
# =========================
qa_chain = create_stuff_documents_chain(llm, prompt_template)

rag_chain = create_retrieval_chain(retriever, qa_chain)

# =========================
# 9. Chat Loop
# =========================
print("Chat with your own data (OpenAI RAG)")

while True:
    question = input("\nAsk your question: ")
    
    if question.lower() in ["exit", "quit"]:
        break
    
    response = rag_chain.invoke({"input": question})
    
    print("\nAnswer:", response["answer"])
# Out:
# Chat with your own data (OpenAI RAG)
#
# Answer: I don't know.
